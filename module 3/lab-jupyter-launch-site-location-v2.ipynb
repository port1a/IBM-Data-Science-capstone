# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo">
#     </a>
# </p>

# %% [markdown]
# # **Launch Sites Locations Analysis with Folium**

# %% [markdown]
# Estimated time needed: **40** minutes

# %% [markdown]
# The launch success rate may depend on many factors such as payload mass, orbit type, and so on. It may also depend on the location and proximities of a launch site, i.e., the initial position of rocket trajectories. Finding an optimal location for building a launch site certainly involves many factors and hopefully we could discover some of the factors by analyzing the existing launch site locations.

# %% [markdown]
# In the previous exploratory data analysis labs, you have visualized the SpaceX launch dataset using `matplotlib` and `seaborn` and discovered some preliminary correlations between the launch site and success rates. In this lab, you will be performing more interactive visual analytics using `Folium`.

# %% [markdown]
# ## Objectives

# %% [markdown]
# This lab contains the following tasks:
# - **TASK 1:** Mark all launch sites on a map
# - **TASK 2:** Mark the success/failed launches for each site on the map
# - **TASK 3:** Calculate the distances between a launch site to its proximities
#
# After completed the above tasks, you should be able to find some geographical patterns about launch sites.

# %% [markdown]
# Let's first import required Python packages for this lab:

# %%
# !pip3 install folium
# !pip3 install wget
# !pip3 install pandas

# %%
import folium
import wget
import pandas as pd

# %%
# Import folium MarkerCluster plugin
from folium.plugins import MarkerCluster
# Import folium MousePosition plugin
from folium.plugins import MousePosition
# Import folium DivIcon plugin
from folium.features import DivIcon

# %% [markdown]
# If you need to refresh your memory about folium, you may download and refer to this previous folium lab:

# %% [markdown]
# [Generating Maps with Python](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/DV0101EN-3-5-1-Generating-Maps-in-Python-py-v2.0.ipynb)

# %% [markdown]
# ## Task 1: Mark all launch sites on a map

# %% [markdown]
# First, let's try to add each site's location on a map using site's latitude and longitude coordinates

# %% [markdown]
# The following dataset with the name `spacex_launch_geo.csv` is an augmented dataset with latitude and longitude added for each site.

# %%
# Download and read the `spacex_launch_geo.csv`
spacex_csv_file = wget.download('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_geo.csv')
spacex_df=pd.read_csv(spacex_csv_file)
# Out:
# 100% [................................................................................] 7710 / 7710

# %%
spacex_df.head()
# Out:
#    Flight Number        Date Time (UTC) Booster Version  Launch Site  \
# 0              1  2010-06-04   18:45:00  F9 v1.0  B0003  CCAFS LC-40
# 1              2  2010-12-08   15:43:00  F9 v1.0  B0004  CCAFS LC-40
# 2              3  2012-05-22    7:44:00  F9 v1.0  B0005  CCAFS LC-40
# 3              4  2012-10-08    0:35:00  F9 v1.0  B0006  CCAFS LC-40
# 4              5  2013-03-01   15:10:00  F9 v1.0  B0007  CCAFS LC-40
#
#                                              Payload  Payload Mass (kg)  \
# 0               Dragon Spacecraft Qualification Unit                0.0
# 1  Dragon demo flight C1, two CubeSats,  barrel o...                0.0
# 2                             Dragon demo flight C2+              525.0
# 3                                       SpaceX CRS-1              500.0
# 4                                       SpaceX CRS-2              677.0
#
#        Orbit         Customer        Landing Outcome  class        Lat  \
# 0        LEO           SpaceX  Failure   (parachute)      0  28.562302
# 1  LEO (ISS)  NASA (COTS) NRO  Failure   (parachute)      0  28.562302
# 2  LEO (ISS)      NASA (COTS)             No attempt      0  28.562302
# 3  LEO (ISS)       NASA (CRS)             No attempt      0  28.562302
# 4  LEO (ISS)       NASA (CRS)             No attempt      0  28.562302
#
#         Long
# 0 -80.577356
# 1 -80.577356
# 2 -80.577356
# 3 -80.577356
# 4 -80.577356

# %% [markdown]
# Now, you can take a look at what are the coordinates for each site.

# %%
# Select relevant sub-columns: `Launch Site`, `Lat(Latitude)`, `Long(Longitude)`, `class`
spacex_df = spacex_df[['Launch Site', 'Lat', 'Long', 'class']]
launch_sites_df = spacex_df.groupby(['Launch Site'], as_index=False).first()
launch_sites_df = launch_sites_df[['Launch Site', 'Lat', 'Long']]
launch_sites_df
# Out:
#     Launch Site        Lat        Long
# 0   CCAFS LC-40  28.562302  -80.577356
# 1  CCAFS SLC-40  28.563197  -80.576820
# 2    KSC LC-39A  28.573255  -80.646895
# 3   VAFB SLC-4E  34.632834 -120.610745

# %% [markdown]
# Above coordinates are just plain numbers that can not give you any intuitive insights about where are those launch sites. If you are very good at geography, you can interpret those numbers directly in your mind. If not, that's fine too. Let's visualize those locations by pinning them on a map.

# %% [markdown]
# We first need to create a folium `Map` object, with an initial center location to be NASA Johnson Space Center at Houston, Texas.

# %%
# Start location is NASA Johnson Space Center
nasa_coordinate = [29.559684888503615, -95.0830971930759]
site_map = folium.Map(location=nasa_coordinate, zoom_start=10)

# %% [markdown]
# We could use `folium.Circle` to add a highlighted circle area with a text label on a specific coordinate. For example,

# %%
# Create a blue circle at NASA Johnson Space Center's coordinate with a popup label showing its name
circle = folium.Circle(nasa_coordinate, radius=1000, color='#d35400', fill=True).add_child(folium.Popup('NASA Johnson Space Center'))
# Create a blue circle at NASA Johnson Space Center's coordinate with a icon showing its name
marker = folium.map.Marker(
    nasa_coordinate,
    # Create an icon as a text label
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % 'NASA JSC',
        )
    )
site_map.add_child(circle)
site_map.add_child(marker)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7a36bf7cc31247c09f61f94992f0acbc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7a36bf7cc31247c09f61f94992f0acbc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7a36bf7cc31247c09f61f94992f0acbc = L.map(
#                 &quot;map_7a36bf7cc31247c09f61f94992f0acbc&quot;,
#                 {
#                     center: [29.559684888503615, -95.0830971930759],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f18191068947298c6aa5f9fe2c402dfc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f18191068947298c6aa5f9fe2c402dfc.addTo(map_7a36bf7cc31247c09f61f94992f0acbc);
#
#
#             var circle_cc050da6437c593414abeb9878925570 = L.circle(
#                 [29.559684888503615, -95.0830971930759],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d35400&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d35400&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7a36bf7cc31247c09f61f94992f0acbc);
#
#
#         var popup_decfef25a4f957c7bcac6792a599be86 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0aff35cb1753a24ee955f0599ba9c855 = $(`&lt;div id=&quot;html_0aff35cb1753a24ee955f0599ba9c855&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NASA Johnson Space Center&lt;/div&gt;`)[0];
#                 popup_decfef25a4f957c7bcac6792a599be86.setContent(html_0aff35cb1753a24ee955f0599ba9c855);
#
#
#
#         circle_cc050da6437c593414abeb9878925570.bindPopup(popup_decfef25a4f957c7bcac6792a599be86)
#         ;
#
#
#
#
#             var marker_1aa9c18540fe4db7d02a83be3255d706 = L.marker(
#                 [29.559684888503615, -95.0830971930759],
#                 {
# }
#             ).addTo(map_7a36bf7cc31247c09f61f94992f0acbc);
#
#
#             var div_icon_dba7266e072c26fdf177d36515c9107c = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:#d35400;\&quot;\u003e\u003cb\u003eNASA JSC\u003c/b\u003e\u003c/div\u003e&quot;,
#   &quot;iconSize&quot;: [20, 20],
#   &quot;iconAnchor&quot;: [0, 0],
#   &quot;className&quot;: &quot;empty&quot;,
# });
#             marker_1aa9c18540fe4db7d02a83be3255d706.setIcon(div_icon_dba7266e072c26fdf177d36515c9107c);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# and you should find a small yellow circle near the city of Houston and you can zoom-in to see a larger circle.

# %% [markdown]
# Now, let's add a circle for each launch site in data frame `launch_sites`

# %% [markdown]
# _TODO:_  Create and add `folium.Circle` and `folium.Marker` for each launch site on the site map

# %% [markdown]
# An example of folium.Circle:

# %% [markdown]
# `folium.Circle(coordinate, radius=1000, color='#000000', fill=True).add_child(folium.Popup(...))`

# %% [markdown]
# An example of folium.Marker:

# %% [markdown]
# `folium.map.Marker(coordinate, icon=DivIcon(icon_size=(20,20),icon_anchor=(0,0), html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % 'label', ))`

# %%
lats = [lat for lat in launch_sites_df['Lat']]
longs = [long for long in launch_sites_df['Long']]
coordinates = list(zip(lats,longs))
coordinates = [list(coordinate) for coordinate in coordinates]
coordinates
# Out:
# [[28.56230197, -80.57735648],
#  [28.56319718, -80.57682003],
#  [28.57325457, -80.64689529],
#  [34.63283416, -120.6107455]]

# %%
# Initial the map
site_map = folium.Map(location=nasa_coordinate, zoom_start=5)
# For each launch site, add a Circle object based on its coordinate (Lat, Long) values. In addition, add Launch site name as a popup label
circle_ccafs = folium.Circle(coordinates[0], radius=200, color='red', fill=True).add_child(folium.Popup('CCAFS LC-40'))
marker_ccafs = folium.map.Marker(
    coordinates[0],
    # Create an icon as a text label
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color: red;"><b>%s</b></div>' % 'CCAFS LC-40',
        )
    )
site_map.add_child(circle_ccafs)
site_map.add_child(marker_ccafs)

circle_slc = folium.Circle(coordinates[1], radius=100, color='blue', fill=True).add_child(folium.Popup('CCAFS SLC-40'))
marker_slc = folium.map.Marker(
    coordinates[1],
    # Create an icon as a text label
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:blue;"><b>%s</b></div>' % 'CCAFS SLC-40',
        )
    )
site_map.add_child(circle_slc)
site_map.add_child(marker_slc)

circle_klc = folium.Circle(coordinates[2], radius=300, color='purple', fill=True).add_child(folium.Popup('KSC LC-39A'))
marker_klc = folium.map.Marker(
    coordinates[2],
    # Create an icon as a text label
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:purple;"><b>%s</b></div>' % 'KSC LC-39A',
        )
    )
site_map.add_child(circle_klc)
site_map.add_child(marker_klc)

circle_vafb = folium.Circle(coordinates[3], radius=100, color='yellow', fill=True).add_child(folium.Popup('VAFB SLC-4E'))
marker_vafb = folium.map.Marker(
    coordinates[3],
    # Create an icon as a text label
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:yellow;"><b>%s</b></div>' % 'VAFB SLC-4E',
        )
    )
site_map.add_child(circle_vafb)
site_map.add_child(marker_vafb)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9464f42288a44bc4b452befc961e6d73 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9464f42288a44bc4b452befc961e6d73&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9464f42288a44bc4b452befc961e6d73 = L.map(
#                 &quot;map_9464f42288a44bc4b452befc961e6d73&quot;,
#                 {
#                     center: [29.559684888503615, -95.0830971930759],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ce7cb9ac4f484da7892d8973cfb3d57f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ce7cb9ac4f484da7892d8973cfb3d57f.addTo(map_9464f42288a44bc4b452befc961e6d73);
#
#
#             var circle_232c7ee7cd5cfecad2cf6824748918e5 = L.circle(
#                 [28.56230197, -80.57735648],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 200, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9464f42288a44bc4b452befc961e6d73);
#
#
#         var popup_cb0a816825d1b8344936c91c236bb5b2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_733f78b4c18b25c63b4f460765a05ad9 = $(`&lt;div id=&quot;html_733f78b4c18b25c63b4f460765a05ad9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40&lt;/div&gt;`)[0];
#                 popup_cb0a816825d1b8344936c91c236bb5b2.setContent(html_733f78b4c18b25c63b4f460765a05ad9);
#
#
#
#         circle_232c7ee7cd5cfecad2cf6824748918e5.bindPopup(popup_cb0a816825d1b8344936c91c236bb5b2)
#         ;
#
#
#
#
#             var marker_0c0a238758de39d9929ea4b9d55d6bb9 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(map_9464f42288a44bc4b452befc961e6d73);
#
#
#             var div_icon_575756ee0622397c3e0993dce55f0b7c = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color: red;\&quot;\u003e\u003cb\u003eCCAFS LC-40\u003c/b\u003e\u003c/div\u003e&quot;,
#   &quot;iconSize&quot;: [20, 20],
#   &quot;iconAnchor&quot;: [0, 0],
#   &quot;className&quot;: &quot;empty&quot;,
# });
#             marker_0c0a238758de39d9929ea4b9d55d6bb9.setIcon(div_icon_575756ee0622397c3e0993dce55f0b7c);
#
#
#             var circle_2957ef2ec63e4339734124886c07beef = L.circle(
#                 [28.56319718, -80.57682003],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 100, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9464f42288a44bc4b452befc961e6d73);
#
#
#         var popup_f7a776d95cf8b63521f2bafe172544ed = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cc04b3a97bfa412cb995d0904ff39b73 = $(`&lt;div id=&quot;html_cc04b3a97bfa412cb995d0904ff39b73&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS SLC-40&lt;/div&gt;`)[0];
#                 popup_f7a776d95cf8b63521f2bafe172544ed.setContent(html_cc04b3a97bfa412cb995d0904ff39b73);
#
#
#
#         circle_2957ef2ec63e4339734124886c07beef.bindPopup(popup_f7a776d95cf8b63521f2bafe172544ed)
#         ;
#
#
#
#
#             var marker_19c23528da04a5a8d355c05cf37ebb04 = L.marker(
#                 [28.56319718, -80.57682003],
#                 {
# }
#             ).addTo(map_9464f42288a44bc4b452befc961e6d73);
#
#
#             var div_icon_8186326fed6dc54312051896c0cd98e0 = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:blue;\&quot;\u003e\u003cb\u003eCCAFS SLC-40\u003c/b\u003e\u003c/div\u003e&quot;,
#   &quot;iconSize&quot;: [20, 20],
#   &quot;iconAnchor&quot;: [0, 0],
#   &quot;className&quot;: &quot;empty&quot;,
# });
#             marker_19c23528da04a5a8d355c05cf37ebb04.setIcon(div_icon_8186326fed6dc54312051896c0cd98e0);
#
#
#             var circle_7f210099a2dd31a810adeb326d1074ab = L.circle(
#                 [28.57325457, -80.64689529],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;purple&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &q

# %% [markdown]
# The generated map with marked launch sites should look similar to the following:

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/images/launch_site_markers.png">
# </center>

# %% [markdown]
# Now, you can explore the map by zoom-in/out the marked areas
# , and try to answer the following questions:
# - Are all launch sites in proximity to the Equator line?
# - Are all launch sites in very close proximity to the coast?
#
# Also please try to explain your findings.

# %% [markdown]
# # Task 2: Mark the success/failed launches for each site on the map

# %% [markdown]
# Next, let's try to enhance the map by adding the launch outcomes for each site, and see which sites have high success rates.
# Recall that data frame spacex_df has detailed launch records, and the `class` column indicates if this launch was successful or not

# %%
spacex_df.drop(columns=['Lat', 'Long']).groupby('Launch Site').value_counts()
# Out:
# Launch Site   class
# CCAFS LC-40   0        19
#               1         7
# CCAFS SLC-40  0         4
#               1         3
# KSC LC-39A    1        10
#               0         3
# VAFB SLC-4E   0         6
#               1         4
# dtype: int64

# %% [markdown]
# Next, let's create markers for all launch records.
# If a launch was successful `(class=1)`, then we use a green marker and if a launch was failed, we use a red marker `(class=0)`

# %% [markdown]
# Note that a launch only happens in one of the four launch sites, which means many launch records will have the exact same coordinate. Marker clusters can be a good way to simplify a map containing many markers having the same coordinate.

# %% [markdown]
# Let's first create a `MarkerCluster` object

# %%
marker_cluster = MarkerCluster()

# %% [markdown]
# _TODO:_ Create a new column in `launch_sites` dataframe called `marker_color` to store the marker colors based on the `class` value

# %%
# Apply a function to check the value of `class` column
# If class=1, marker_color value will be green
# If class=0, marker_color value will be red

# %%
# Function to assign color to launch outcome
def assign_marker_color(launch_outcome):
    if launch_outcome == 1:
        return 'green'
    else:
        return 'red'
    
spacex_df['marker_color'] = spacex_df['class'].apply(assign_marker_color)
spacex_df.tail(10)
# Out:
#      Launch Site        Lat       Long  class marker_color
# 46    KSC LC-39A  28.573255 -80.646895      1        green
# 47    KSC LC-39A  28.573255 -80.646895      1        green
# 48    KSC LC-39A  28.573255 -80.646895      1        green
# 49  CCAFS SLC-40  28.563197 -80.576820      1        green
# 50  CCAFS SLC-40  28.563197 -80.576820      1        green
# 51  CCAFS SLC-40  28.563197 -80.576820      0          red
# 52  CCAFS SLC-40  28.563197 -80.576820      0          red
# 53  CCAFS SLC-40  28.563197 -80.576820      0          red
# 54  CCAFS SLC-40  28.563197 -80.576820      1        green
# 55  CCAFS SLC-40  28.563197 -80.576820      0          red

# %% [markdown]
# _TODO:_ For each launch result in `spacex_df` data frame, add a `folium.Marker` to `marker_cluster`

# %%
for index, record in spacex_df.iterrows():
    print(record)
# Out:
# Flight Number                                           1
# Date                                           2010-06-04
# Time (UTC)                                       18:45:00
# Booster Version                            F9 v1.0  B0003
# Launch Site                                   CCAFS LC-40
# Payload              Dragon Spacecraft Qualification Unit
# Payload Mass (kg)                                     0.0
# Orbit                                                 LEO
# Customer                                           SpaceX
# Landing Outcome                     Failure   (parachute)
# class                                                   0
# Lat                                             28.562302
# Long                                           -80.577356
# marker_color                                          red
# Name: 0, dtype: object
# Flight Number                                                        2
# Date                                                        2010-12-08
# Time (UTC)                                                    15:43:00
# Booster Version                                         F9 v1.0  B0004
# Launch Site                                                CCAFS LC-40
# Payload              Dragon demo flight C1, two CubeSats,  barrel o...
# Payload Mass (kg)                                                  0.0
# Orbit                                                        LEO (ISS)
# Customer                                               NASA (COTS) NRO
# Landing Outcome                                  Failure   (parachute)
# class                                                                0
# Lat                                                          28.562302
# Long                                                        -80.577356
# marker_color                                                       red
# Name: 1, dtype: object
# Flight Number                             3
# Date                             2012-05-22
# Time (UTC)                          7:44:00
# Booster Version              F9 v1.0  B0005
# Launch Site                     CCAFS LC-40
# Payload              Dragon demo flight C2+
# Payload Mass (kg)                     525.0
# Orbit                             LEO (ISS)
# Customer                        NASA (COTS)
# Landing Outcome                  No attempt
# class                                     0
# Lat                               28.562302
# Long                             -80.577356
# marker_color                            red
# Name: 2, dtype: object
# Flight Number                     4
# Date                     2012-10-08
# Time (UTC)                  0:35:00
# Booster Version      F9 v1.0  B0006
# Launch Site             CCAFS LC-40
# Payload                SpaceX CRS-1
# Payload Mass (kg)             500.0
# Orbit                     LEO (ISS)
# Customer                 NASA (CRS)
# Landing Outcome          No attempt
# class                             0
# Lat                       28.562302
# Long                     -80.577356
# marker_color                    red
# Name: 3, dtype: object
# Flight Number                     5
# Date                     2013-03-01
# Time (UTC)                 15:10:00
# Booster Version      F9 v1.0  B0007
# Launch Site             CCAFS LC-40
# Payload                SpaceX CRS-2
# Payload Mass (kg)             677.0
# Orbit                     LEO (ISS)
# Customer                 NASA (CRS)
# Landing Outcome          No attempt
# class                             0
# Lat                       28.562302
# Long                     -80.577356
# marker_color                    red
# Name: 4, dtype: object
# Flight Number                  7
# Date                  2013-12-03
# Time (UTC)              22:41:00
# Booster Version          F9 v1.1
# Launch Site          CCAFS LC-40
# Payload                    SES-8
# Payload Mass (kg)         3170.0
# Orbit                        GTO
# Customer                     SES
# Landing Outcome       No attempt
# class                          0
# Lat                    28.562302
# Long                  -80.577356
# marker_color                 red
# Name: 5, dtype: object
# Flight Number                  8
# Date                  2014-01-06
# Time (UTC)              22:06:00
# Booster Version          F9 v1.1
# Launch Site          CCAFS LC-40
# Payload                Thaicom 6
# Payload Mass (kg)         3325.0
# Orbit                        GTO
# Customer                 Thaicom
# Landing Outcome       No attempt
# class                          0
# Lat                    28.562302
# Long                  -80.577356
# marker_color                 red
# Name: 6, dtype: object
# Flight Number                         9
# Date                         2014-04-18
# Time (UTC)                     19:25:00
# Booster Version                 F9 v1.1
# Launch Site                 CCAFS LC-40
# Payload                    SpaceX CRS-3
# Payload Mass (kg)                2296.0
# Orbit                         LEO (ISS)
# Customer                     NASA (CRS)
# Landing Outcome      Controlled (ocean)
# class                                 0
# Lat                           28.562302
# Long                         -80.577356
# marker_color                        red
# Name: 7, dtype: object
# Flight Number                                             10
# Date                                              2014-07-14
# Time (UTC)                                          15:15:00
# Booster Version                                      F9 v1.1
# Launch Site                                      CCAFS LC-40
# Payload              OG2 Mission 1  6 Orbcomm-OG2 satellites
# Payload Mass (kg)                                     1316.0
# Orbit                                                    LEO
# Customer                                             Orbcomm
# Landing Outcome                           Controlled (ocean)
# class                                                      0
# Lat                                                28.562302
# Long                                              -80.577356
# marker_color                                             red
# Name: 8, dtype: object
# Flight Number                 11
# Date                  2014-08-05
# Time (UTC)               8:00:00
# Booster Version          F9 v1.1
# Launch Site          CCAFS LC-40
# Payload                AsiaSat 8
# Payload Mass (kg)         4535.0
# Orbit                        GTO
# Customer                 AsiaSat
# Landing Outcome       No attempt
# class                          0
# Lat                    28.562302
# Long                  -80.577356
# marker_color                 red
# Name: 9, dtype: object
# Flight Number                   12
# Date                    2014-09-07
# Time (UTC)                 5:00:00
# Booster Version      F9 v1.1 B1011
# Launch Site            CCAFS LC-40
# Payload                  AsiaSat 6
# Payload Mass (kg)           4428.0
# Orbit                          GTO
# Customer                   AsiaSat
# Landing Outcome         No attempt
# class                            0
# Lat                      28.562302
# Long                    -80.577356
# marker_color                   red
# Name: 10, dtype: object
# Flight Number                          13
# Date                           2014-09-21
# Time (UTC)                        5:52:00
# Booster Version             F9 v1.1 B1010
# Launch Site                   CCAFS LC-40
# Payload                      SpaceX CRS-4
# Payload Mass (kg)                  2216.0
# Orbit                           LEO (ISS)
# Customer                       NASA (CRS)
# Landing Outcome      Uncontrolled (ocean)
# class                                   0
# Lat                             28.562302
# Long                           -80.577356
# marker_color                          red
# Name: 11, dtype: object
# Flight Number                           14
# Date                            2015-01-10
# Time (UTC)                         9:47:00
# Booster Version              F9 v1.1 B1012
# Launch Site                    CCAFS LC-40
# Payload                       SpaceX CRS-5
# Payload Mass (kg)                   2395.0
# Orbit                            LEO (ISS)
# Customer                        NASA (CRS)
# Landing Outcome      Failure  (drone ship)
# class                                    0
# Lat                              28.562302
# Long                            -80.577356
# marker_color                           red
# Name: 12, dtype: object
# Flight Number                              15
# Date                               2015-02-11
# Time (UTC)                           23:03:00
# Booster Version                 F9 v1.1 B1013
# Launch Site                       CCAFS LC-40
# Payload                                DSCOVR
# Payload Mass (kg)                       570.0
# Orbit                            Sun–Earth L1
# Customer             U.S. Air Force NASA NOAA
# Landing Outcome            Controlled (ocean)
# class                                       0
# Lat                                 28.562302
# Long                               -80.577356
# marker_color                              red
# Name: 13, dtype: object
# Flight Number                                16
# Date                                 2015-03-02
# Time (UTC)                              3:50:00
# Booster Version                   F9 v1.1 B1014
# Launch Site                         CCAFS LC-40
# Payload              ABS-3A Eutelsat 115 West B
# Payload Mass (kg)                        4159.0
# Orbit                                       GTO
# Customer                           ABS Eutelsat
# Landing Outcome                      No attempt
# class                                         0
# Lat                                   28.562302
# Long                                 -80.577356
# marker_color                                red
# Name: 14, dtype: object
# Flight Number                           17
# Date                            2015-04-14
# Time (UTC)                        20:10:00
# Booster Version              F9 v1.1 B1015
# Launch Site                    CCAFS LC-40
# Payload                       SpaceX CRS-6
# Payload Mass (kg)                   1898.0
# Orbit                            LEO (ISS)
# Customer                        NASA (CRS)
# Landing Outcome      Failure  (drone ship)
# class                                    0
# Lat                              28.562302
# Long                            -80.577356
# marker_color                           red
# Name: 15, dtype: object
# Flight Number                                        18
# Date                                         2015-04-27
# Time (UTC)                                     23:03:00
# Booster Version                           F9 v1.1 B1016
# Launch Site                                 CCAFS LC-40
# Payload                    TürkmenÄlem 52°E / MonacoSAT
# Payload Mass (kg)                                4707.0
# Orbit                                               GTO
# Customer             Turkmenistan National Space Agency
# Landing Outcome                              No attempt
# class                                                 0
# Lat                                           28.562302
# Long                                         -80.577356
# marker_color                                        red
# Name: 16, dtype: object
# Flight Number                             19
# Date                              2015-06-28
# Time (UTC)                          14:21:00
# Booster Version                F9 v1.1 B1018
# Launch Site                      CCAFS LC-40
# Payload                         SpaceX CRS-7
# Payload Mass (kg)                     1952.0
# Orbit                              LEO (ISS)
# Customer                          NASA (CRS)
# Landing Outcome      Precluded  (drone ship)
# class                                      1
# Lat                                28.562302
# Long                              -80.577356
# marker_color                           green
# Name: 17, dtype: object
# Flight Number                                               20
# Date                                                2015-12-22
# Time (UTC)                                             1:29:00
# Booster Version                                    F9 FT B1019
# Launch Site                                        CCAFS LC-40
# Payload              OG2 Mission 2   11 Orbcomm-OG2 satellites
# Payload Mass (kg)                                       2034.0
# Orbit                                                      LEO
# Customer                                               Orbcomm
# Landing Outcome                          Success  (ground pad)
# class                                                        1
# Lat                                                  28.562302
# Long                                                -80.577356
# marker_color                                             green
# Name: 18, dtype: object
# Flight Number                          22
# Date                           2016-03-04
# Time (UTC)                       23:35:00
# Booster Version               F9 FT B1020
# Launch Site                   CCAFS LC-40
# Payload                             SES-9
# Payload Mass (kg)                  5271.0
# Orbit                                 GTO
# Customer                              SES
# Landing Outcome      Failure (drone ship)
# class                                   0
# Lat                             28.562302
# Long                           -80.577356
# marker_color                          red
# Name: 19, dtype: object
# Flight Number                           23
# Date                            2016-04-08
# Time (UTC)                        20:43:00
# Booster Version              F9 FT B1021.1
# Launch Site                    CCAFS LC-40
# Payload                       SpaceX CRS-8
# Payload Mass (kg)                   3136.0
# Orbit                            LEO (ISS)
# Customer                        NASA (CRS)
# Landing Outcome      Success  (drone ship)
# class                                    1
# Lat                              28.562302
# Long                            -80.577356
# marker_color                         green
# Name: 20, dtype: object
# Flight Number                            24
# Date                             2016-05-06
# Time (UTC)                          5:21:00
# Booster Version                 F9 FT B1022
# Launch Site                     CCAFS LC-40
# Payload                            JCSAT-14
# Payload Mass (kg)                    4696.0
# Orbit                                   GTO
# Customer             SKY Perfect JSAT Group
# Landing Outcome        Success (drone ship)
# class                                     1
# Lat                               28.562302
# Long                             -80.577356
# marker_color                          green
# Name: 21, dtype: object
# Flight Number                           25
# Date                            2016-05-27
# Time (UTC)                        21:39:00
# Booster Version              F9 FT B1023.1
# Launch Site                    CCAFS LC-40
# Payload                          Thaicom 8
# Payload Mass (kg)                   3100.0
# Orbit                                  GTO
# Customer                           Thaicom
# Landing Outcome      Success  (drone ship)
# class                                    1
# Lat                              28.562302
# Long                            -80.577356
# marker_color                         green
# Name: 22, dtype: object
# Flight Number                                26
# Date                                 2016-06-15
# Time (UTC)                             14:29:00
# Booster Version                     F9 FT B1024
# Launch Site                         CCAFS LC-40
# Payload              ABS-2A Eutelsat 117 West B
# Payload Mass (kg)                        3600.0
# Orbit                                       GTO
# Customer                           ABS Eutelsat
# Landing Outcome           Failure  (drone ship)
# class                                         0
# Lat                                   28.562302
# Long                                 -80.577356
# marker_color                                red
# Name: 23, dtype: object
# Flight Number                          27
# Date                           2016-07-18
# Time (UTC)                        4:45:00
# Booster Version             F9 FT B1025.1
# Launch Site                   CCAFS LC-40
# Payload                      SpaceX CRS-9
# Payload Mass (kg)                  2257.0
# Orbit                           LEO (ISS)
# Customer                       NASA (CRS)
# Landing Outcome      Success (ground pad)
# class                                   1
# Lat                             28.562302
# Long                           -80.577356
# marker_color                        green
# Name: 24, dtype: object
# Flight Number                            28
# Date                             2016-08-14
# Time (UTC)                          5:26:00
# Booster Version                 F9 FT B1026
# Launch Site                     CCAFS LC-40
# Payload                            JCSAT-16
# Payload Mass (kg)                    4600.0
# Orbit                                   GTO
# Customer             SKY Perfect JSAT Group
# Landing Outcome        Success (drone ship)
# class                                     1
# Lat                               28.562302
# Long                             -80.577356
# marker_color                          green
# Name: 25, dtype: object
# Flight Number                           6
# Date                           2013-09-29
# Time (UTC)                       16:00:00
# Booster Version            F9 v1.1  B1003
# Launch Site                   VAFB SLC-4E
# Payload                          CASSIOPE
# Payload Mass (kg)                   500.0
# Orbit                           Polar LEO
# Customer                              MDA
# Landing Outcome      Uncontrolled (ocean)
# class                                   0
# Lat                             34.632834
# Long                          -120.610745
# marker_color                          red
# Name: 26, dtype: object
# Flight Number                          21
# Date                           2016-01-17
# Time (UTC)                       18:42:00
# Booster Version             F9 v1.1 B1017
# Launch Site                   VAFB SLC-4E
# Payload                           Jason-3
# Payload Mass (kg)                   553.0
# Orbit                                 LEO
# Customer             NASA (LSP) NOAA CNES
# Landing Outcome      Failure (drone ship)
# class                                   0
# Lat                             34.632834
# Long                          -120.610745
# marker_color                          red
# Name: 27, dtype: object
# Flight Number                            29
# Date                             2017-01-14
# Time (UTC)                         17:54:00
# Booster Version               F9 FT B1029.1
# Launch Site                     VAFB SLC-4E
# Payload                      Iridium NEXT 1
# Payload Mass (kg)                    9600.0
# Orbit                             Polar LEO
# Customer             Iridium Communications
# Landing Outcome       Success  (drone ship)
# class                                     1
# Lat                               34.632834
# Long                            -120.610745
# marker_color                          green
# Name: 28, dtype: object
# Flight Number                            37
# Date                             2017-06-25
# Time (UTC)                         20:25:00
# Booster Version               F9 FT B1036.1
# Launch Site                     VAFB SLC-4E
# Payload                      Iridium NEXT 2
# Payload Mass (kg)                    9600.0
# Orbit                                   LEO
# Customer             Iridium Communications
# Landing Outcome        Success (drone ship)
# class                                     1
# Lat                               34.632834
# Long                            -120.610745
# marker_color                          green
# Name: 29, dtype: object
# Flight Number                          40
# Date                           2017-08-24
# Time (UTC)                       18:51:00
# Booster Version             F9 FT B1038.1
# Launch Site                   VAFB SLC-4E
# Payload                        Formosat-5
# Payload Mass (kg)                   475.0
# Orbit                                 SSO
# Customer                             NSPO
# Landing Outcome      Success (drone ship)
# class                                   1
# Lat                             34.632834
# Long                          -120.610745
# marker_color                        green
# Name: 30, dtype: object
# Flight Number                            42
# Date                             2017-10-09
# Time (UTC)                         12:37:00
# Booster Version               F9 B4 B1041.1
# Launch Site                     VAFB SLC-4E
# Payload                      Iridium NEXT 3
# Payload Mass (kg)                    9600.0
# Orbit                             Polar LEO
# Customer             Iridium Communications
# Landing Outcome        Success (drone ship)
# class                                     1
# Lat                               34.632834
# Long                            -120.610745
# marker_color                          green
# Name: 31, dtype: object
# Flight Number                            46
# Date                             2017-12-23
# Time (UTC)                          1:27:00
# Booster Version              F9 FT  B1036.2
# Launch Site                     VAFB SLC-4E
# Payload                      Iridium NEXT 4
# Payload Mass (kg)                    9600.0
# Orbit                             Polar LEO
# Customer             Iridium Communications
# Landing Outcome          Controlled (ocean)
# class                                     0
# Lat                               34.632834
# Long                            -120.610745
# marker_color                            red
# Name: 32, dtype: object
# Flight Number                                49
# Date                                 2018-02-22
# Time (UTC)                             14:17:00
# Booster Version                  F9 FT  B1038.2
# Launch Site                         VAFB SLC-4E
# Payload                       Paz  Tintin A & B
# Payload Mass (kg)                        2150.0
# Orbit                                       SSO
# Customer             Hisdesat exactEarth SpaceX
# Landing Outcome                      No attempt
# class                                         0
# Lat                                   34.632834
# Long                                -120.610745
# marker_color                                red
# Name: 33, dtype: object
# Flight Number                            51
# Date                             2018-03-30
# Time (UTC)                         14:14:00
# Booster Version              F9 B4  B1041.2
# Launch Site                     VAFB SLC-4E
# Payload                      Iridium NEXT 5
# Payload Mass (kg)                    9600.0
# Orbit                             Polar LEO
# Customer             Iridium Communications
# Landing Outcome                  No attempt
# class                                     0
# Lat                               34.632834
# Long                            -120.610745
# marker_color                            red
# Name: 34, dtype: object
# Flight Number                                       55
# Date                                        2018-05-22
# Time (UTC)                                    19:47:58
# Booster Version                         F9 B4  B1043.2
# Launch Site                                VAFB SLC-4E
# Payload                 Iridium NEXT 6   GRACE-FO 1, 2
# Payload Mass (kg)                               6460.0
# Orbit                                        Polar LEO
# Customer             Iridium Communications GFZ • NASA
# Landing Outcome                             No attempt
# class                                                0
# Lat                                          34.632834
# Long                                       -120.610745
# marker_color                                       red
# Name: 35, dtype: object
# Flight Number                          30
# Date                           2017-02-19
# Time (UTC)                       14:39:00
# Booster Version             F9 FT B1031.1
# Launch Site                    KSC LC-39A
# Payload                     SpaceX CRS-10
# Payload Mass (kg)                  2490.0
# Orbit                           LEO (ISS)
# Customer                       NASA (CRS)
# Landing Outcome      Success (ground pad)
# class                                   1
# Lat                             28.573255
# Long                           -80.646895
# marker_color                        green
# Name: 36, dtype: object
# Flight Number                 31
# Date                  2017-03-16
# Time (UTC)               6:00:00
# Booster Version      F9 FT B1030
# Launch Site           KSC LC-39A
# Payload              EchoStar 23
# Payload Mass (kg)         5600.0
# Orbit                        GTO
# Customer                EchoStar
# Landing Outcome       No attempt
# class                          0
# Lat                    28.573255
# Long                  -80.646895
# marker_color                 red
# Name: 37, dtype: object
# Flight Number                          32
# Date                           2017-03-30
# Time (UTC)                       22:27:00
# Booster Version            F9 FT  B1021.2
# Launch Site                    KSC LC-39A
# Payload                            SES-10
# Payload Mass (kg)                  5300.0
# Orbit                                 GTO
# Customer                              SES
# Landing Outcome      Success (drone ship)
# class                                   1
# Lat                             28.573255
# Long                           -80.646895
# marker_color                        green
# Name: 38, dtype: object
# Flight Number                          33
# Date                           2017-05-01
# Time (UTC)                       11:15:00
# Booster Version             F9 FT B1032.1
# Launch Site                    KSC LC-39A
# Payload                           NROL-76
# Payload Mass (kg)                 3696.65
# Orbit                                 LEO
# Customer                              NRO
# Landing Outcome      Success (ground pad)
# class                                   1
# Lat                             28.573255
# Long                           -80.646895
# marker_color                        green
# Name: 39, dtype: object
# Flight Number                   34
# Date                    2017-05-15
# Time (UTC)                23:21:00
# Booster Version        F9 FT B1034
# Launch Site             KSC LC-39A
# Payload              Inmarsat-5 F4
# Payload Mass (kg)           6070.0
# Orbit                          GTO
# Customer                  Inmarsat
# Landing Outcome         No attempt
# class                            0
# Lat                      28.573255
# Long                    -80.646895
# marker_color                   red
# Name: 40, dtype: object
# Flight Number                          35
# Date                           2017-06-03
# Time (UTC)                       21:07:00
# Booster Version             F9 FT B1035.1
# Launch Site                    KSC LC-39A
# Payload                     SpaceX CRS-11
# Payload Mass (kg)                  2708.0
# Orbit                           LEO (ISS)
# Customer                       NASA (CRS)
# Landing Outcome      Success (ground pad)
# class                                   1
# Lat                             28.573255
# Long                           -80.646895
# marker_color                        green
# Name: 41, dtype: object
# Flight Number                          36
# Date                           2017-06-23
# Time (UTC)                       19:10:00
# Booster Version            F9 FT  B1029.2
# Launch Site                    KSC LC-39A
# Payload                     BulgariaSat-1
# Payload Mass (kg)                  3669.0
# Orbit                                 GTO
# Customer                        Bulsatcom
# Landing Outcome      Success (drone ship)
# class                                   1
# Lat                             28.573255
# Long                           -80.646895
# marker_color                        green
# Name: 42, dtype: object
# Flight Number                  38
# Date                   2017-07-05
# Time (UTC)               23:38:00
# Booster Version       F9 FT B1037
# Launch Site            KSC LC-39A
# Payload              Intelsat 35e
# Payload Mass (kg)          6761.0
# Orbit                         GTO
# Customer                 Intelsat
# Landing Outcome        No attempt
# class                           0
# Lat                     28.573255
# Long                   -80.646895
# marker_color                  red
# Name: 43, dtype: object
# Flight Number                          39
# Date                           2017-08-14
# Time (UTC)                       16:31:00
# Booster Version             F9 B4 B1039.1
# Launch Site                    KSC LC-39A
# Payload                     SpaceX CRS-12
# Payload Mass (kg)                  3310.0
# Orbit                           LEO (ISS)
# Customer                       NASA (CRS)
# Landing Outcome      Success (ground pad)
# class                                   1
# Lat                             28.573255
# Long                           -80.646895
# marker_color                        green
# Name: 44, dtype: object
# Flight Number                          41
# Date                           2017-09-07
# Time (UTC)                       14:00:00
# Booster Version             F9 B4 B1040.1
# Launch Site                    KSC LC-39A
# Payload                Boeing X-37B OTV-5
# Payload Mass (kg)                  4990.0
# Orbit                                 LEO
# Customer                   U.S. Air Force
# Landing Outcome      Success (ground pad)
# class                                   1
# Lat                             28.573255
# Long                           -80.646895
# marker_color                        green
# Name: 45, dtype: object
# Flight Number                           43
# Date                            2017-10-11
# Time (UTC)                        22:53:00
# Booster Version             F9 FT  B1031.2
# Launch Site                     KSC LC-39A
# Payload              SES-11 / EchoStar 105
# Payload Mass (kg)                   5200.0
# Orbit                                  GTO
# Customer                      SES EchoStar
# Landing Outcome       Success (drone ship)
# class                                    1
# Lat                              28.573255
# Long                            -80.646895
# marker_color                         green
# Name: 46, dtype: object
# Flight Number                          44
# Date                           2017-10-30
# Time (UTC)                       19:34:00
# Booster Version             F9 B4 B1042.1
# Launch Site                    KSC LC-39A
# Payload                       Koreasat 5A
# Payload Mass (kg)                  3500.0
# Orbit                                 GTO
# Customer                   KT Corporation
# Landing Outcome      Success (drone ship)
# class                                   1
# Lat                             28.573255
# Long                           -80.646895
# marker_color                        green
# Name: 47, dtype: object
# Flight Number                          54
# Date                           2018-05-11
# Time (UTC)                       20:14:00
# Booster Version            F9 B5  B1046.1
# Launch Site                    KSC LC-39A
# Payload                     Bangabandhu-1
# Payload Mass (kg)                  3600.0
# Orbit                                 GTO
# Customer               Thales-Alenia/BTRC
# Landing Outcome      Success (drone ship)
# class                                   1
# Lat                             28.573255
# Long                           -80.646895
# marker_color                        green
# Name: 48, dtype: object
# Flight Number                          45
# Date                           2017-12-15
# Time (UTC)                       15:36:00
# Booster Version            F9 FT  B1035.2
# Launch Site                  CCAFS SLC-40
# Payload                     SpaceX CRS-13
# Payload Mass (kg)                  2205.0
# Orbit                           LEO (ISS)
# Customer                       NASA (CRS)
# Landing Outcome      Success (ground pad)
# class                                   1
# Lat                             28.563197
# Long                            -80.57682
# marker_color                        green
# Name: 49, dtype: object
# Flight Number                          47
# Date                           2018-01-08
# Time (UTC)                        1:00:00
# Booster Version             F9 B4 B1043.1
# Launch Site                  CCAFS SLC-40
# Payload                              Zuma
# Payload Mass (kg)                 3696.65
# Orbit                                 LEO
# Customer                 Northrop Grumman
# Landing Outcome      Success (ground pad)
# class                                   1
# Lat                             28.563197
# Long                            -80.57682
# marker_color                        green
# Name: 50, dtype: object
# Flight Number                        48
# Date                         2018-01-31
# Time (UTC)                     21:25:00
# Booster Version          F9 FT  B1032.2
# Launch Site                CCAFS SLC-40
# Payload               GovSat-1 / SES-16
# Payload Mass (kg)                4230.0
# Orbit                               GTO
# Customer                            SES
# Landing Outcome      Controlled (ocean)
# class                                 0
# Lat                           28.563197
# Long                          -80.57682
# marker_color                        red
# Name: 51, dtype: object
# Flight Number                            50
# Date                             2018-03-06
# Time (UTC)                          5:33:00
# Booster Version                 F9 B4 B1044
# Launch Site                    CCAFS SLC-40
# Payload              Hispasat 30W-6  PODSat
# Payload Mass (kg)                    6092.0
# Orbit                                   GTO
# Customer                Hispasat  NovaWurks
# Landing Outcome                  No attempt
# class                                     0
# Lat                               28.563197
# Long                              -80.57682
# marker_color                            red
# Name: 52, dtype: object
# Flight Number                    52
# Date                     2018-04-02
# Time (UTC)                 20:30:00
# Booster Version      F9 B4  B1039.2
# Launch Site            CCAFS SLC-40
# Payload               SpaceX CRS-14
# Payload Mass (kg)            2647.0
# Orbit                     LEO (ISS)
# Customer                 NASA (CRS)
# Landing Outcome          No attempt
# class                             0
# Lat                       28.563197
# Long                      -80.57682
# marker_color                    red
# Name: 53, dtype: object
# Flight Number                                                  53
# Date                                                   2018-04-18
# Time (UTC)                                               22:51:00
# Booster Version                                     F9 B4 B1045.1
# Launch Site                                          CCAFS SLC-40
# Payload              Transiting Exoplanet Survey Satellite (TESS)
# Payload Mass (kg)                                           362.0
# Orbit                                                         HEO
# Customer                                               NASA (LSP)
# Landing Outcome                              Success (drone ship)
# class                                                           1
# Lat                                                     28.563197
# Long                                                    -80.57682
# marker_color                                                green
# Name: 54, dtype: object
# Flight Number                    56
# Date                     2018-06-04
# Time (UTC)                  4:45:00
# Booster Version      F9 B4  B1040.2
# Launch Site            CCAFS SLC-40
# Payload                      SES-12
# Payload Mass (kg)            5384.0
# Orbit                           GTO
# Customer                        SES
# Landing Outcome          No attempt
# class                             0
# Lat                       28.563197
# Long                      -80.57682
# marker_color                    red
# Name: 55, dtype: object

# %%
# Add marker_cluster to current site_map
site_map.add_child(marker_cluster)

# for each row in spacex_df data frame
# create a Marker object with its coordinate
# and customize the Marker's icon property to indicate if this launch was successed or failed, 
# e.g., icon=folium.Icon(color='white', icon_color=row['marker_color']
for index, row in spacex_df.iterrows():
    # create and add a Marker cluster to the site map
    coordinate = [row['Lat'], row['Long']]
    folium.map.Marker(coordinate, icon=folium.Icon(color='white',icon_color=row['marker_color'])).add_to(marker_cluster)
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9464f42288a44bc4b452befc961e6d73 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9464f42288a44bc4b452befc961e6d73&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9464f42288a44bc4b452befc961e6d73 = L.map(
#                 &quot;map_9464f42288a44bc4b452befc961e6d73&quot;,
#                 {
#                     center: [29.559684888503615, -95.0830971930759],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ce7cb9ac4f484da7892d8973cfb3d57f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ce7cb9ac4f484da7892d8973cfb3d57f.addTo(map_9464f42288a44bc4b452befc961e6d73);
#
#
#             var circle_232c7ee7cd5cfecad2cf6824748918e5 = L.circle(
#                 [28.56230197, -80.57735648],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 200, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9464f42288a44bc4b452befc961e6d73);
#
#
#         var popup_cb0a816825d1b8344936c91c236bb5b2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_733f78b4c18b25c63b4f460765a05ad9 = $(`&lt;div id=&quot;html_733f78b4c18b25c63b4f460765a05ad9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40&lt;/div&gt;`)[0];
#                 popup_cb0a816825d1b8344936c91c236bb5b2.setContent(html_733f78b4c18b25c63b4f460765a05ad9);
#
#
#
#         circle_232c7ee7cd5cfecad2cf6824748918e5.bindPopup(popup_cb0a816825d1b8344936c91c236bb5b2)
#         ;
#
#
#
#
#             var marker_0c0a238758de39d9929ea4b9d55d6bb9 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(map_9464f42288a44bc4b452befc961e6d73);
#
#
#             var div_icon_575756ee0622397c3e0993dce55f0b7c = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color: red;\&quot;\u003e\u003cb\u003eCCAFS LC-40\u003c/b\u003e\u003c/div\u003e&quot;,
#   &quot;iconSize&quot;: [20, 20],
#   &quot;iconAnchor&quot;: [0, 0],
#   &quot;className&quot;: &quot;empty&quot;,
# });
#             marker_0c0a238758de39d9929ea4b9d55d6bb9.setIcon(div_icon_575756ee0622397c3e0993dce55f0b7c);
#
#
#             var circle_2957ef2ec63e4339734124886c07beef = L.circle(
#                 [28.56319718, -80.57682003],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 100, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9464f42288a44bc4b452befc961e6d73);
#
#
#         var popup_f7a776d95cf8b63521f2bafe172544ed = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cc04b3a97bfa412cb995d0904ff39b73 = $(`&lt;div id=&quot;html_cc04b3a97bfa412cb995d0904ff39b73&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS SLC-40&lt;/div&gt;`)[0];
#                 popup_f7a776d95cf8b63521f2bafe172544ed.setContent(html_cc04b3a97bfa412cb995d0904ff39b73);
#
#
#
#         circle_2957ef2ec63e4339734124886c07beef.bindPopup(popup_f7a776d95cf8b63521f2bafe172544ed)
#         ;
#
#
#
#
#             var marker_19c23528da04a5a8d355c05cf37ebb04 = L.marker(
#                 [28.56319718, -80.57682003],
#                 {
# }
#             ).addTo(map_9464f42288a44bc4b452befc961e6d73);
#
#
#             var div_icon_8186326fed6dc54312051896c0cd98e0 = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:blue;\&quot;\u003e\u003cb\u003eCCAFS SLC-40\u003c/b\u003e\u003c/div\u003e&quot;,
#   &quot;iconSize&quot;: [20, 20],
#   &quot;iconAnchor&quot;:

# %% [markdown]
# Your updated map may look like the following screenshots:

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/images/launch_site_marker_cluster.png">
# </center>

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/images/launch_site_marker_cluster_zoomed.png">
# </center>

# %% [markdown]
# From the color-labeled markers in marker clusters, you should be able to easily identify which launch sites have relatively high success rates.

# %% [markdown]
# # TASK 3: Calculate the distances between a launch site to its proximities

# %% [markdown]
# Next, we need to explore and analyze the proximities of launch sites.

# %% [markdown]
# Let's first add a `MousePosition` on the map to get coordinate for a mouse over a point on the map. As such, while you are exploring the map, you can easily find the coordinates of any points of interests (such as railway)

# %%
# Add Mouse Position to get the coordinate (Lat, Long) for a mouse over on the map
formatter = "function(num) {return L.Util.formatNum(num, 5);};"
mouse_position = MousePosition(
    position='topright',
    separator=' Long: ',
    empty_string='NaN',
    lng_first=False,
    num_digits=20,
    prefix='Lat:',
    lat_formatter=formatter,
    lng_formatter=formatter,
)

site_map.add_child(mouse_position)
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9464f42288a44bc4b452befc961e6d73 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9464f42288a44bc4b452befc961e6d73&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9464f42288a44bc4b452befc961e6d73 = L.map(
#                 &quot;map_9464f42288a44bc4b452befc961e6d73&quot;,
#                 {
#                     center: [29.559684888503615, -95.0830971930759],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ce7cb9ac4f484da7892d8973cfb3d57f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ce7cb9ac4f484da7892d8973cfb3d57f.addTo(map_9464f42288a44bc4b452befc961e6d73);
#
#
#             var circle_232c7ee7cd5cfecad2cf6824748918e5 = L.circle(
#                 [28.56230197, -80.57735648],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 200, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9464f42288a44bc4b452befc961e6d73);
#
#
#         var popup_cb0a816825d1b8344936c91c236bb5b2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_733f78b4c18b25c63b4f460765a05ad9 = $(`&lt;div id=&quot;html_733f78b4c18b25c63b4f460765a05ad9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40&lt;/div&gt;`)[0];
#                 popup_cb0a816825d1b8344936c91c236bb5b2.setContent(html_733f78b4c18b25c63b4f460765a05ad9);
#
#
#
#         circle_232c7ee7cd5cfecad2cf6824748918e5.bindPopup(popup_cb0a816825d1b8344936c91c236bb5b2)
#         ;
#
#
#
#
#             var marker_0c0a238758de39d9929ea4b9d55d6bb9 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(map_9464f42288a44bc4b452befc961e6d73);
#
#
#             var div_icon_575756ee0622397c3e0993dce55f0b7c = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color: red;\&quot;\u003e\u003cb\u003eCCAFS LC-40\u003c/b\u003e\u003c/div\u003e&quot;,
#   &quot;iconSize&quot;: [20, 20],
#   &quot;iconAnchor&quot;: [0, 0],
#   &quot;className&quot;: &quot;empty&quot;,
# });
#             marker_0c0a238758de39d9929ea4b9d55d6bb9.setIcon(div_icon_575756ee0622397c3e0993dce55f0b7c);
#
#
#             var circle_2957ef2ec63e4339734124886c07beef = L.circle(
#                 [28.56319718, -80.57682003],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 100, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9464f42288a44bc4b452befc961e6d73);
#
#
#         var popup_f7a776d95cf8b63521f2bafe172544ed = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cc04b3a97bfa412cb995d0904ff39b73 = $(`&lt;div id=&quot;html_cc04b3a97bfa412cb995d0904ff39b73&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS SLC-40&lt;/div&gt;`)[0];
#                 popup_f7a776d95cf8b63521f2bafe172544ed.setContent(html_cc04b3a97bfa412cb995d0904ff39b73);
#
#
#
#         circle_2957ef2ec63e4339734124886c07beef.bindPopup(popup_f7a776d95cf8b63521f2bafe172544ed)
#         ;
#
#
#
#
#             var marker_19c23528da04a5a8d355c05cf37ebb04 = L.marker(
#                 [28.56319718, -80.57682003],
#                 {
# }
#             ).addTo(map_9464f42288a44bc4b452befc961e6d73);

# %% [markdown]
# Now zoom in to a launch site and explore its proximity to see if you can easily find any railway, highway, coastline, etc. Move your mouse to these points and mark down their coordinates (shown on the top-left) in order to the distance to the launch site.

# %% [markdown]
# You can calculate the distance between two points on the map based on their `Lat` and `Long` values using the following method:

# %%
from math import sin, cos, sqrt, atan2, radians

def calculate_distance(lat1, lon1, lat2, lon2):
    # approximate radius of earth in km
    R = 6373.0

    lat1 = radians(lat1)
    lon1 = radians(lon1)
    lat2 = radians(lat2)
    lon2 = radians(lon2)

    dlon = lon2 - lon1
    dlat = lat2 - lat1

    a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))

    distance = R * c
    return distance

# %% [markdown]
# _TODO:_ Mark down a point on the closest coastline using MousePosition and calculate the distance between the coastline point and the launch site.

# %%
# find coordinate of the closet coastline
# e.g.,: Lat: 28.56367  Lon: -80.57163
# distance_coastline = calculate_distance(launch_site_lat, launch_site_lon, coastline_lat, coastline_lon)

# %% [markdown]
# _TODO:_ After obtained its coordinate, create a `folium.Marker` to show the distance

# %%
# Create and add a folium.Marker on your selected closest coastline point on the map
# Display the distance between coastline point and launch site using the icon property 
# for example
# distance_marker = folium.Marker(
#    coordinate,
#    icon=DivIcon(
#        icon_size=(20,20),
#        icon_anchor=(0,0),
#        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance),
#        )
#    )

# %% [markdown]
# _TODO:_ Draw a `PolyLine` between a launch site to the selected coastline point

# %%
# Create a `folium.PolyLine` object using the coastline coordinates and launch site coordinate
# lines=folium.PolyLine(locations=coordinates, weight=1)
site_map.add_child(lines)

# %% [markdown]
# Your updated map with distance line should look like the following screenshot:

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/images/launch_site_marker_distance.png">
# </center>

# %% [markdown]
# _TODO:_ Similarly, you can draw a line betwee a launch site to its closest city, railway, highway, etc. You need to use `MousePosition` to find the their coordinates on the map first

# %% [markdown]
# A railway map symbol may look like this:

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/images/railway.png">
# </center>

# %% [markdown]
# A highway map symbol may look like this:

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/images/highway.png">
# </center>

# %% [markdown]
# A city map symbol may look like this:

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/images/city.png">
# </center>

# %%
# Create a marker with distance to a closest city, railway, highway, etc.
# Draw a line between the marker to the launch site

# %% [markdown]
# After you plot distance lines to the proximities, you can answer the following questions easily:
# - Are launch sites in close proximity to railways?
# - Are launch sites in close proximity to highways?
# - Are launch sites in close proximity to coastline?
# - Do launch sites keep certain distance away from cities?
#
# Also please try to explain your findings.

# %% [markdown]
# # Next Steps:
#
# Now you have discovered many interesting insights related to the launch sites' location using folium, in a very interactive way. Next, you will need to build a dashboard using Ploty Dash on detailed launch records.

# %% [markdown]
# ## Authors

# %% [markdown]
# [Yan Luo](https://www.linkedin.com/in/yan-luo-96288783/)

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Joseph Santarcangelo

# %% [markdown]
# ## Change Log

# %% [markdown]
# |Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2021-05-26|1.0|Yan|Created the initial version|

# %% [markdown]
# Copyright © 2021 IBM Corporation. All rights reserved.
